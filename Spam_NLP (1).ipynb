# %%
import re
import nltk
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split 
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import  Pipeline

# %%
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

# %%
data={"email":["Click here to win a lottery prize.",
              "Work from home , no prior experince required.",
              "Call on this number to make payment.",
              "Loan on less interest rate, Click Here.",
              "Amazon Gift Card worth Rs.500. Grab it now.",
              "Urgent!Get your KYC done in 24-48 hr.",
              " I phone starting from Rs. 1000, limited offfer, Buy now!.",
              "Get your Adhar card verified on this portal , CLick . From pmo Office.",
              "We processed your AppNo. 92732. yuor profile is matched with Infosys & Genpact Opening. Click her to applr now",
              "Start your session at DUO Lingo. click here!",
              "You google account was logged in a different device.",
              "your Google Account was succesfully recovred . Review now."],
      "label":["spam","spam","spam","spam","not spam","spam","spam","spam","spam","not spam","not spam","spam"]
      }

# %%
df=pd.read_csv('spam.csv')

# %%
df
# Out:
#          label                                              email Unnamed: 2  \
# 0     not spam  gojurongpointcrazyavailablebugisngreatworldlae...        NaN
# 1     not spam                                 oklarjokingwifuoni        NaN
# 2         spam  freeentry2wklycompwinfacupfinaltkts21stmay2005...        NaN
# 3     not spam                        udunsayearlyhorucalreadysay        NaN
# 4     not spam                  nahdontthinkgousflifearoundthough        NaN
# ...        ...                                                ...        ...
# 5567      spam  2ndtimetried2contactuuå750poundprize2claimeasy...        NaN
# 5568  not spam                            ì_bgoingesplanadefrhome        NaN
# 5569  not spam                          pitywamoodsoanysuggestion        NaN
# 5570  not spam  guybitchingactedlikeidinterestedbuyingsomethin...        NaN
# 5571  not spam                                       rofltruename        NaN
#
#      Unnamed: 3 Unnamed: 4
# ...

# %%
def clean (text):
    text=text.lower()
    text=re.sub(r'[^\w\s]','',text)
    tokens=word_tokenize(text)
    tokens=[WordNetLemmatizer().lemmatize(word) for word in tokens]
    tokens=[word for word in tokens if word not in stopwords.words('english')]
    return "".join(tokens)

# %%
df['email']=df['email'].apply(clean)

# %%
df
# Out:
#          label                                              email Unnamed: 2  \
# 0     not spam  gojurongpointcrazyavailablebugisngreatworldlae...        NaN
# 1     not spam                                 oklarjokingwifuoni        NaN
# 2         spam  freeentry2wklycompwinfacupfinaltkts21stmay2005...        NaN
# 3     not spam                        udunsayearlyhorucalreadysay        NaN
# 4     not spam                  nahdontthinkgousflifearoundthough        NaN
# ...        ...                                                ...        ...
# 5567      spam  2ndtimetried2contactuuå750poundprize2claimeasy...        NaN
# 5568  not spam                            ì_bgoingesplanadefrhome        NaN
# 5569  not spam                          pitywamoodsoanysuggestion        NaN
# 5570  not spam  guybitchingactedlikeidinterestedbuyingsomethin...        NaN
# 5571  not spam                                       rofltruename        NaN
#
#      Unnamed: 3 Unnamed: 4
# ...

# %%
x_train, x_test,y_train, y_test=train_test_split(df['email'],df['label'],test_size=0.2, random_state=42)

# %%
pipeline=Pipeline([('tfidf',TfidfVectorizer()),('classifier' , MultinomialNB())])

# %%
pipeline.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('tfidf', TfidfVectorizer()), ('classifier', MultinomialNB())])

# %%
user_email=input("Enter you email")
cleaned_email=clean(user_email)
pred=pipeline.predict([cleaned_email])
print("Result:", pred[0])
# Out:
# Enter you email We processed your AppNo. 92732. yuor profile is matched with Infosys & Genpact Opening. Click her to applr now
# Result: not spam
